# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
hd = pd.read_csv("sk-data/heart-disease.csv")
x = hd.drop("target", axis=1)
y = hd["target"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
np.random.seed(42)
clf = RandomForestClassifier()
clf.fit(x_train, y_train)
elements = ["age",	"sex",	"cp",	"trestbps",	"chol",	"fbs",	"restecg",	"thalach",	"exang",	"oldpeak",	"slope",	"ca",	"thal"]
lis = []
for i in elements:
    enteres = float(input(f"Please enter your info about {i}: "))
    lis.append(enteres)
numpy_array = np.array(lis)
predicting = clf.predict(numpy_array.reshape(1,-1))
if predicting == 0:
    print("Congrats! you dont have a Heart disiese.")
else:
    print("Be carefull! You might have a Heart disiese.")
# Out:
# Please enter your info about age:  17
# Please enter your info about sex:  1
# Please enter your info about cp:  1212
# Please enter your info about trestbps:  121
# Please enter your info about chol:  100
# Please enter your info about fbs:  1212
# Please enter your info about restecg:  1212
# Please enter your info about thalach:  1212
# Please enter your info about exang:  123
# Please enter your info about oldpeak:  4324
# Please enter your info about slope:  43242342
# Please enter your info about ca:  2342342
# Please enter your info about thal:  34234234
# Congrats! you dont have a Heart disiese.
# C:\Users\Mustafa akbari\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
cross_val_score(clf, x, y, cv=10)
# Out:
# array([0.87096774, 0.83870968, 0.87096774, 0.93333333, 0.9       ,
#        0.8       , 0.83333333, 0.83333333, 0.7       , 0.76666667])

# %%
clf.score(x_test, y_test)
# Out:
# 0.819672131147541

# %%
y_probs = clf.predict_proba(x_test)

# %%
y_probs_positive = y_probs[:,1]
y_probs_positive
# Out:
# array([0.92, 0.4 , 0.98, 0.94, 0.82, 0.92, 0.81, 0.77, 0.03, 0.61, 0.62,
#        0.82, 0.01, 0.59, 0.84, 0.29, 0.2 , 0.04, 0.97, 0.33, 0.95, 0.08,
#        0.92, 0.69, 0.37, 0.66, 0.06, 0.13, 0.99, 0.33, 0.72, 0.98, 0.41,
#        0.69, 0.6 , 0.93, 0.71, 0.85, 0.39, 0.44, 0.2 , 0.21, 0.83, 0.11,
#        0.88, 0.8 , 0.78, 0.78, 0.73, 0.92, 0.08, 0.26, 0.56, 0.03, 0.17,
#        0.92, 0.6 , 0.93, 0.04, 0.87, 0.52])

# %%
fpr, tpr, tresholds = roc_curve(y_test, y_probs_positive)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.04166667, 0.04166667, 0.04166667, 0.04166667, 0.04166667,
#        0.04166667, 0.08333333, 0.16666667, 0.16666667, 0.16666667,
#        0.16666667, 0.29166667, 0.29166667, 0.375     , 0.375     ,
#        0.41666667, 0.41666667, 0.45833333, 0.54166667, 0.66666667,
#        0.75      , 0.79166667, 0.95833333, 1.        ])

# %%
## creating a function for ploting the ROC curve

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color="Orange", label="ROC")
    plt.plot([0,1], [0,1], color="Darkblue", linestyle="--" ,label="Gussing")
    plt.xlabel("False psostive rate (fpr)")
    plt.ylabel("True posotive rate (tpe)")
    plt.title("Riciver under oprating charactristic (ROC) curve")
    plt.legend()
    plt.show()
plot_roc_curve(fpr, tpr)

# %%
roc_auc_score(y_test, y_probs_positive)
# Out:
# 0.9138513513513514

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier

# %%
np.random.seed(234)
df = pd.read_csv("sk-data/cardio_train.csv", sep=";")
df = df.drop("id", axis=1)
df["age"] = (df["age"]/365.2).round(2)
x = df.drop("cardio", axis=1)
y = df["cardio"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
models = {"Logistic": LogisticRegression(), 
         "RandomForrest": RandomForestClassifier(n_jobs=-1),
         "KNN": KNeighborsClassifier(n_jobs=-1, n_neighbors=14),
         "MLP": MLPClassifier(hidden_layer_sizes=32)}
model_score = {}
for name, model in models.items():
    model.fit(x_train, y_train)
    model_score[name] = model.score(x_test, y_test)
model_score
# Out:
# C:\Users\Mustafa akbari\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'Logistic': 0.7028571428571428,
#  'RandomForrest': 0.7083571428571429,
#  'KNN': 0.7082857142857143,
#  'MLP': 0.6965}
